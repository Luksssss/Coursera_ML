# %% [markdown]
# # Programming Assignment:
# ## Готовим LDA по рецептам

# %% [markdown]
# Как вы уже знаете, в тематическом моделировании делается предположение о том, что для определения тематики порядок слов в документе не важен; об этом гласит гипотеза «мешка слов». Сегодня мы будем работать с несколько нестандартной для тематического моделирования коллекцией, которую можно назвать «мешком ингредиентов», потому что на состоит из рецептов блюд разных кухонь. Тематические модели ищут слова, которые часто вместе встречаются в документах, и составляют из них темы. Мы попробуем применить эту идею к рецептам и найти кулинарные «темы». Эта коллекция хороша тем, что не требует предобработки. Кроме того, эта задача достаточно наглядно иллюстрирует принцип работы тематических моделей.
#
# Для выполнения заданий, помимо часто используемых в курсе библиотек, потребуются модули *json* и *gensim*. Первый входит в дистрибутив Anaconda, второй можно поставить командой
#
# *pip install gensim*
#
# **conda install --name py27 gensim**
#
# Построение модели занимает некоторое время. На ноутбуке с процессором Intel Core i7 и тактовой частотой 2400 МГц на построение одной модели уходит менее 10 минут.

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# Коллекция дана в json-формате: для каждого рецепта известны его id, кухня (cuisine) и список ингредиентов, в него входящих. Загрузить данные можно с помощью модуля json (он входит в дистрибутив Anaconda):

# %%
import json

# %%
with open("recipes.json") as f:
    recipes = json.load(f)

# %%
print recipes[0]
# Out:
# {u'cuisine': u'greek', u'id': 10259, u'ingredients': [u'romaine lettuce', u'black olives', u'grape tomatoes', u'garlic', u'pepper', u'purple onion', u'seasoning', u'garbanzo beans', u'feta cheese crumbles']}

# %% [markdown]
# ### Составление корпуса

# %%
from gensim import corpora, models
import numpy as np
# Out:
# /home/lukashov/anaconda3/envs/py27/lib/python2.7/site-packages/smart_open/ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')

# %% [markdown]
# Наша коллекция небольшая, и целиком помещается в оперативную память. Gensim может работать с такими данными и не требует их сохранения на диск в специальном формате. Для этого коллекция должна быть представлена в виде списка списков, каждый внутренний список соответствует отдельному документу и состоит из его слов. Пример коллекции из двух документов:
#
# [["hello", "world"], ["programming", "in", "python"]]
#
# Преобразуем наши данные в такой формат, а затем создадим объекты corpus и dictionary, с которыми будет работать модель.

# %%
texts = [recipe["ingredients"] for recipe in recipes]
dictionary = corpora.Dictionary(texts)   # составляем словарь
corpus = [dictionary.doc2bow(text) for text in texts]  # составляем корпус документов

# %%
print texts[0]
print corpus[50]
# Out:
# [u'romaine lettuce', u'black olives', u'grape tomatoes', u'garlic', u'pepper', u'purple onion', u'seasoning', u'garbanzo beans', u'feta cheese crumbles']
# [(28, 1), (29, 1), (52, 1), (96, 1), (230, 1), (294, 1), (295, 1), (296, 1), (297, 1), (298, 1), (299, 1), (300, 1)]

# %%
dictionary.get(5)
# Out:
# u'pepper'

# %% [markdown]
# У объекта dictionary есть полезная переменная dictionary.token2id, позволяющая находить соответствие между ингредиентами и их индексами.

# %% [markdown]
# ### Обучение модели
# Вам может понадобиться [документация](https://radimrehurek.com/gensim/models/ldamodel.html) LDA в gensim.

# %% [markdown]
# __Задание 1.__ Обучите модель LDA с 40 темами, установив количество проходов по коллекции 5 и оставив остальные параметры по умолчанию.
#
#
# Затем вызовите метод модели *show_topics*, указав количество тем 40 и количество токенов 10, и сохраните результат (топы ингредиентов в темах) в отдельную переменную. Если при вызове метода *show_topics* указать параметр *formatted=True*, то топы ингредиентов будет удобно выводить на печать, если *formatted=False*, будет удобно работать со списком программно. Выведите топы на печать, рассмотрите темы, а затем ответьте на вопрос:
#
# Сколько раз ингредиенты "salt", "sugar", "water", "mushrooms", "chicken", "eggs" встретились среди топов-10 всех 40 тем? При ответе __не нужно__ учитывать составные ингредиенты, например, "hot water".
#
# Передайте 6 чисел в функцию save_answers1 и загрузите сгенерированный файл в форму.
#
# У gensim нет возможности фиксировать случайное приближение через параметры метода, но библиотека использует numpy для инициализации матриц. Поэтому, по утверждению автора библиотеки, фиксировать случайное приближение нужно командой, которая написана в следующей ячейке. __Перед строкой кода с построением модели обязательно вставляйте указанную строку фиксации random.seed.__

# %%
np.random.seed(76543)
# здесь код для построения модели:
# %time ldamodel = models.ldamodel.LdaModel(corpus, id2word=dictionary, num_topics=40, passes=5)
# Out:
# CPU times: user 1min 58s, sys: 1.17 s, total: 1min 59s
# Wall time: 49 s

# %%
top = ldamodel.show_topics(num_topics=40, num_words=10, formatted=False)
# Out:
# [(0,
#   [(u'garlic cloves', 0.08417177),
#    (u'chopped onion', 0.06965804),
#    (u'cooking spray', 0.06782779),
#    (u'salt', 0.06464641),
#    (u'water', 0.043428298),
#    (u'fat free less sodium chicken broth', 0.041910786),
#    (u'ground red pepper', 0.03999348),
#    (u'sliced green onions', 0.03912287),
#    (u'black pepper', 0.02634012),
#    (u'spinach', 0.023790007)]),
#  (1,
#   [(u'corn kernels', 0.076162696),
#    (u'diced onions', 0.06478067),
#    (u'tortillas', 0.054170214),
#    (u'salt and ground black pepper', 0.052615125),
#    (u'cream cheese', 0.05244322),
#    (u'1% low-fat milk', 0.04376323),
#    (u'vegetable stock', 0.037935086),
#    (u'sliced black olives', 0.03697521),
#    (u'cream cheese, soften', 0.035920784),
#    (u'chopped fresh chives', 0.03484748)]),
#  (2,
#   [(u'olive oil', 0.08121181),
#    (u'fresh parsley', 0.05471344),
#    (u'crushed red pepper', 0.05158975),
#    (u'salt', 0.041959926),
#    (u'grated parmesan cheese', 0.040684987),
#    (u'garlic cloves', 0.039174125),
#    (u'cherry tomatoes', 0.03413268),
#    (u'low salt chicken broth', 0.032585654),
#    (u'butter', 0.031271342),
#    (u'green beans', 0.028732283)]),
#  (3,
#   [(u'bacon', 0.07386834),
#    (u'salt', 0.07292463),
#    (u'red pepper flakes', 0.060946085),
#    (u'ground black pepper', 0.046570424),
#    (u'garlic', 0.04622089),
#    (u'pasta', 0.041793447),
#    (u'onions', 0.037137832),
#    (u'olive oil', 0.036318656),
#    (u'chicken thighs', 0.036304213),
#    (u'fresh dill', 0.030322066)]),
#  (4,
#   [(u'all-purpose flour', 0.13009132),
#    (u'large eggs', 0.12599166),
#    (u'salt', 0.088994294),
#    (u'milk', 0.08013886),
#    (u'butter', 0.070112474),
#    (u'sugar', 0.049980137),
#    (u'baking powder', 0.04088548),
#    (u'powdered sugar', 0.030803535),
#    (u'vegetable oil', 0.025907619),
#    (u'large egg whites', 0.024166485)]),
#  (5,
#   [(u'dry white wine', 0.078586705),
#    (u'shallots', 0.06441841),
#    (u'olive oil', 0.051531643),
#    (u'salt', 0.039216243),
#    (u'ground cloves', 0.030400397),
#    (u'white wine vinegar', 0.029700408),
#    (u'butter', 0.029078882),
#    (u'arborio rice', 0.02847186),
#    (u'saffron threads', 0.024808608),
#    (u'ground nutmeg', 0.023230618)]),
#  (6,
#   [(u'leeks', 0.075189956),
#    (u'dry red wine', 0.073530994),
#    (u'pork tenderloin', 0.04998755),
#    (u'reduced sodium soy sauce', 0.044726826),
#    (u'cilantro sprigs', 0.044033714),
#    (u'peppercorns', 0.034536134),
#    (u'carrots', 0.030967345),
#    (u'granny smith apples', 0.02550304),
#    (u'beef broth', 0.024558892),
#    (u'cremini mushrooms', 0.024070695)]),
#  (7,
#   [(u'soy sauce', 0.088227294),
#    (u'sesame oil', 0.054307047),
#    (u'scallions', 0.04537694),
#    (u'green onions', 0.04440766),
#    (u'corn starch', 0.039320927),
#    (u'rice vinegar', 0.03883131),
#    (u'sugar', 0.036080897),
#    (u'garlic', 0.03386268),
#    (u'vegetable oil', 0.030898172),
#    (u'fresh ginger', 0.026808374)]),
#  (8,
#   [(u'garlic powder', 0.17690319),
#    (u'cayenne pepper', 0.11679163),
#    (u'onion powder', 0.06639312),
#    (u'smoked paprika', 0.044006277),
#    (u'ground black pepper', 0.042889163),
#    (u'black pepper', 0.035148367),
#    (u'fine sea salt', 0.027586356),
#    (u'salt', 0.025603501),
#    (u'dried thyme', 0.022975313),
#    (u'greek yogurt', 0.022910874)]),
#  (9,
#   [(u'olive oil', 0.06838013),
#    (u'salt', 0.06288496),
#    (u'purple onion', 0.05891011),
#    (u'garlic cloves', 0.05474761),
#    (u'fresh lemon juice', 0.047944065),
#    (u'extra-virgin olive oil', 0.047271006),
#    (u'fresh basil', 0.045465507),
#    (u'plum tomatoes', 0.045009818),
#    (u'ground black pepper', 0.041061472),
#    (u'balsamic vinegar', 0.03294537)]),
#  (10,
#   [(u'broccoli florets', 0.053727508),
#    (u'lettuce leaves', 0.05072321),
#    (u'chili flakes', 0.040980645),
#    (u'cr\xe8me fra\xeeche', 0.039928373),
#    (u'radishes', 0.036516417),
#    (u'greek style plain yogurt', 0.03175258),
#    (u'pork sausages', 0.031665746),
#    (u'sharp cheddar cheese', 0.030972669),
#    (u'watercress', 0.028878994),
#    (u'quickcooking grits', 0.027067585)]),
#  (11,
#   [(u'lime juice', 0.102194086),
#    (u'lime', 0.09133106),
#    (u'salt', 0.047873747),
#    (u'garlic', 0.043787647),
#    (u'chopped cilantro', 0.04242771),
#    (u'fresh cilantro', 0.04145919),
#    (u'purple onion', 0.0395448),
#    (u'jalapeno chilies', 0.034777388),
#    (u'mango', 0.02623268),
#    (u'olive oil', 0.021458164)]),
#  (12,
#   [(u'cheese', 0.08288024),
#    (u'ricotta cheese', 0.080211684),
#    (u'orange juice', 0.07569578),
#    (u'sliced mushrooms', 0.05108882),
#    (u'baby spinach', 0.050212525),
#    (u'vegetable oil cooking spray', 0.04459705),
#    (u'frozen chopped spinach', 0.031937376),
#    (u'italian sausage', 0.028930997),
#    (u'part-skim ricotta cheese', 0.027697356),
#    (u'part-skim mozzarella cheese', 0.026522333)]),
#  (13,
#   [(u'diced tomatoes', 0.07813256),
#    (u'dried oregano', 0.07083208),
#    (u'onions', 0.0558519),
#    (u'tomato sauce', 0.051108196),
#    (u'salt', 0.047680724),
#    (u'garlic', 0.044233747),
#    (u'dried basil', 0.03948484),
#    (u'olive oil', 0.039333515),
#    (u'tomato paste', 0.036249716),
#    (u'ground beef', 0.028629338)]),
#  (14,
#   [(u'beef', 0.06628038),
#    (u'onions', 0.05033933),
#    (u'green cabbage', 0.046645347),
#    (u'red wine', 0.044178884),
#    (u'green peas', 0.041962333),
#    (u'goat cheese', 0.03782291),
#    (u'beef stock', 0.03305619),
#    (u'red cabbage', 0.030407658),
#    (u'cooked rice', 0.027899086),
#    (u'chili pepper', 0.027644528)]),
#  (15,
#   [(u'lemon', 0.12790158),
#    (u'sugar', 0.06505046),
#    (u'fresh mint', 0.05939578),
#    (u'orange', 0.04819912),
#    (u'boiling water', 0.04253356),
#    (u'cold water', 0.03353512),
#    (u'water', 0.032981027),
#    (u'ground white pepper', 0.029220024),
#    (u'almonds', 0.027751958),
#    (u'all purpose unbleached flour', 0.02282312)]),
#  (16,
#   [(u'chopped cilantro fresh', 0.07326786),
#    (u'fresh lime juice', 0.06972146),
#    (u'jalapeno chilies', 0.066870205),
#    (u'white onion', 0.053722687),
#    (u'avocado', 0.040314656),
#    (u'garlic cloves', 0.037019853),
#    (u'salt', 0.036022063),
#    (u'coarse salt', 0.030647846),
#    (u'ground cumin', 0.028608521),
#    (u'ground pepper', 0.027162092)]),
#  (17,
#   [(u'zucchini', 0.1291754),
#    (u'eggplant', 0.071087025),
#    (u'onions', 0.06085624),
#    (u'olive oil', 0.05069114),
#    (u'white wine', 0.050018772),
#    (u'garlic', 0.04778684),
#    (u'chopped parsley', 0.04468414),
#    (u'fresh mushrooms', 0.039033078),
#    (u'lean ground beef', 0.035968557),
#    (u'raisins', 0.03276228)]),
#  (18,
#   [(u'parmesan cheese', 0.10686615),
#    (u'salt', 0.07542276),
#    (u'warm water', 0.06602801),
#    (u'olive oil', 0.0540764),
#    (u'bell pepper', 0.05156222),
#    (u'water', 0.04937832),
#    (u'grits', 0.035690833),
#    (u'polenta', 0.031318028),
#    (u'kale', 0.029725786),
#    (u'plain flour', 0.02836023)]),
#  (19,
#   [(u'unsalted butter', 0.13265035),
#    (u'all-purpose flour', 0.07038272),
#    (u'salt', 0.06623665),
#    (u'sugar', 0.055823516),
#    (u'large eggs', 0.054432996),
#    (u'whole milk', 0.0421716),
#    (u'granulated sugar', 0.0417429),
#    (u'buttermilk', 0.0328685),
#    (u'large egg yolks', 0.029630957),
#    (u'baking powder', 0.0283933)]),
#  (20,
#   [(u'red wine vinegar', 0.08784444),
#    (u'flat leaf parsley', 0.06965664),
#    (u'olive oil', 0.05248364),
#    (u'tomatoes', 0.04440109),
#    (u'extra-virgin olive oil', 0.042616926),
#    (u'garlic cloves', 0.041584212),
#    (u'sweet onion', 0.0375637),
#    (u'ground black pepper', 0.034712486),
#    (u'dry bread crumbs', 0.034520872),
#    (u'salt', 0.033066902)]),
#  (21,
#   [(u'chicken broth', 0.21047871),
#    (u'boneless skinless chicken breast halves', 0.08617707),
#    (u'boneless skinless chicken breasts', 0.07813076),
#    (u'cajun seasoning', 0.056837074),
#    (u'juice', 0.037468508),
#    (u'butter', 0.030434774),
#    (u'pepper', 0.029544648),
#    (u'onions', 0.024852995),
#    (u'garlic salt', 0.02159882),
#    (u'boneless chicken breast', 0.021533534)]),
#  (22,
#   [(u'grated parmesan cheese', 0.13138898),
#    (u'olive oil', 0.050161008),
#    (u'mozzarella cheese', 0.048157185),
#    (u'shredded mozzarella cheese', 0.044398185),
#    (u'garlic', 0.037587997),
#    (u'salt', 0.03614238),
#    (u'italian seasoning', 0.035813093),
#    (u'eggs', 0.03495326),
#    (u'pepper', 0.02885666),
#    (u'pasta sauce', 0.026468884)]),
#  (23,
#   [(u'brown sugar', 0.07021599),
#    (u'soy sauce', 0.0460727),
#    (u'salt', 0.044391386),
#    (u'water', 0.044210967),
#    (u'white pepper', 0.042981092),
#    (u'oil', 0.038263906),
#    (u'sugar', 0.038065974),
#    (u'ketchup', 0.03711884),
#    (u'sauce', 0.035626538),
#    (u'garlic', 0.035109043)]),
#  (24,
#   [(u'ground cumin', 0.07469739),
#    (u'salt', 0.044177536),
#    (u'ground coriander', 0.043641683),
#    (u'onions', 0.029024135),
#    (u'garlic', 0.02747043),
#    (u'ground turmeric', 0.024738582),
#    (u'garlic cloves', 0.024009025),
#    (u'vegetable oil', 0.022955334),
#    (u'paprika', 0.022251457),
#    (u'cayenne', 0.021764724)]),
#  (25,
#   [(u'large shrimp', 0.07869277),
#    (u'hot water', 0.07010703),
#    (u'chopped garlic', 0.06510793),
#    (u'peanut oil', 0.05268206),
#    (u'rice wine', 0.046047043),
#    (u'hot red pepper flakes', 0.035946537),
#    (u'corn oil', 0.028698787),
#    (u'fontina cheese', 0.025592266),
#    (u'marsala wine', 0.023869254),
#    (u'seasoning', 0.023670746)]),
#  (26,
#   [(u'mirin', 0.071908556),
#    (u'chickpeas', 0.06316802),
#    (u'mint leaves', 0.043683454),
#    (u'spring onions', 0.04350317),
#    (u'red pepper', 0.04271548),
#    (u'fresh coriander', 0.036621284),
#    (u'sake', 0.036294006),
#    (u'saffron', 0.035252985),
#    (u'soy sauce', 0.0314456),
#    (u'sugar', 0.031282138)]),
#  (27,
#   [(u'heavy cream', 0.16889867),
#    (u'grated nutmeg', 0.05668099),
#    (u'frozen peas', 0.054386802),
#    (u'bread crumbs', 0.04135767),
#    (u'unsalted butter', 0.037560876),
#    (u'bananas', 0.034859005),
#    (u'Tabasco Pepper Sauce', 0.034731336),
#    (u'bread', 0.031325668),
#    (u'mascarpone', 0.02788738),
#    (u'lump crab meat', 0.026599262)]),
#  (28,
#   [(u'oil', 0.10634346),
#    (u'salt', 0.08433464),
#    (u'green chilies', 0.047855895),
#    (u'cilantro leaves', 0.047808222),
#    (u'onions', 0.046337288),
#    (u'cumin seed', 0.04470253),
#    (u'ground turmeric', 0.038288213),
#    (u'water', 0.037419133),
#    (u'red chili peppers', 0.033700034),
#    (u'chili powder', 0.031697083)]),
#  (29,
#   [(u'sour cream', 0.07462643),
#    (u'chili powder', 0.046695035),
#    (u'salsa', 0.04548943),
#    (u'flour tortillas', 0.044969432),
#    (u'black beans', 0.040367767),
#    (u'shredded cheddar cheese', 0.03973018),
#    (u'corn tortillas', 0.037632234),
#    (u'ground cumin', 0.03093948),
#    (u'cilantro', 0.028546073),
#    (u'salt', 0.027160764)]),
#  (30,
#   [(u'sugar', 0.094095565),
#    (u'whipping cream', 0.07995747),
#    (u'egg yolks', 0.07593865),
#    (u'vanilla extract', 0.055063758),
#    (u'butter', 0.04340008),
#    (u'half & half', 0.04261524),
#    (u'egg whites', 0.039017323),
#    (u'sweetened condensed milk', 0.036691222),
#    (u'water', 0.032224502),
#    (u'strawberries', 0.030931063)]),
#  (31,
#   [(u'fish sauce', 0.099714525),
#    (u'coconut milk', 0.04393323),
#    (u'shallots', 0.04099235),
#    (u'sugar', 0.03759515),
#    (u'vegetable oil', 0.03381259),
#    (u'fresh lime juice', 0.033295397),
#    (u'lemongrass', 0.029814279),
#    (u'water', 0.028471159),
#    (u'medium shrimp', 0.023361716),
#    (u'beansprouts', 0.0231539)]),
#  (32,
#   [(u'eggs', 0.13349794),
#    (u'salt', 0.09055754),
#    (u'butter', 0.06111629),
#    (u'flour', 0.05545489),
#    (u'all-purpose flour', 0.055407137),
#    (u'milk', 0.05492474),
#    (u'white sugar', 0.052416425),
#    (u'sugar', 0.035511624),
#    (u'baking powder', 0.03197287),
#    (u'water', 0.021297434)]),
#  (33,
#   [(u'rice', 0.054439444),
#    (u'onions', 0.051631957),
#    (u'chicken breasts', 0.04641736),
#    (u'salt', 0.0460868),
#    (u'coriander', 0.043706965),
#    (u'curry powder', 0.040531125),
#    (u'garlic', 0.03762684),
#    (u'cabbage', 0.03305583),
#    (u'ginger', 0.032561466),
#    (u'ghee', 0.029442828)]),
#  (34,
#   [(u'cinnamon sticks', 0.079063326),
#    (u'clove', 0.07361739),
#    (u'black peppercorns', 0.053733647),
#    (u'garam masala', 0.0448992),
#    (u'chopped tomatoes', 0.03613238),
#    (u'cream', 0.03607574),
#    (u'garlic paste', 0.03350436),
#    (u'coriander seeds', 0.032118585),
#    (u'yoghurt', 0.030220646),
#    (u'bay leaves', 0.026209837)]),
#  (35,
#   [(u'onions', 0.058559474),
#    (u'salt', 0.050931804),
#    (u'green bell pepper', 0.05047846),
#    (u'celery', 0.044689022),
#    (u'dried thyme', 0.032566752),
#    (u'water', 0.030666914),
#    (u'garlic', 0.028280178),
#    (u'bay leaves', 0.027931139),
#    (u'red bell pepper', 0.027552156),
#    (u'shrimp', 0.02730658)]),
#  (36,
#   [(u'salt', 0.09860984),
#    (u'paprika', 0.070299245),
#    (u'onions', 0.06748015),
#    (u'pepper', 0.06434963),
#    (u'potatoes', 0.057595927),
#    (u'carrots', 0.031456277),
#    (u'garlic', 0.031392597),
#    (u'butter', 0.028522385),
#    (u'oregano', 0.027526792),
#    (u'olive oil', 0.02665528)]),
#  (37,
#   [(u'extra-virgin olive oil', 0.13173795),
#    (u'freshly ground pepper', 0.07460467),
#    (u'sea salt', 0.068590716),
#    (u'large garlic cloves', 0.04883593),
#    (u'kosher salt', 0.04624774),
#    (u'garlic cloves', 0.037928768),
#    (u'celery ribs', 0.032366008),
#    (u'fresh oregano', 0.030187877),
#    (u'ground black pepper', 0.030086722),
#    (u'parmigiano reggiano cheese', 0.02937517)]),
#  (38,
#   [(u'chicken', 0.08864278),
#    (u'chicken stock', 0.084292024),
#    (u'yellow onion', 0.05506008),
#    (u'white vinegar', 0.054314107),
#    (u'onions', 0.045047767),
#    (u'ground black pepper', 0.04326869),
#    (u'garlic', 0.04285999),
#    (u'kosher salt', 0.032400034),
#    (u'salt', 0.026785115),
#    (u'water', 0.026231399)]),
#  (39,
#   [(u'mayonaise', 0.12672956),
#    (u'dijon mustard', 0.062804416),
#    (u'cider vinegar', 0.05738003),
#    (u'cracked black pepper', 0.057192296),
#    (u'cheddar cheese', 0.05290602),
#    (u'roma tomatoes', 0.03877668),
#    (u'apple cider vinegar', 0.03770634),
#    (u'white rice', 0.036042877),
#    (u'lemon wedge', 0.035815623),
#    (u'french bread', 0.02656781)])]

# %%
top.count('salt')
# Out:
# 0

# %%
salt = 0
sugar = 0
water = 0
mushrooms = 0
chicken = 0
eggs = 0
# for t, top_words in ldamodel.print_topics(num_topics=40, num_words=10):
#     print "Topic", t, ":", top_words

for top_words in top:
    for w in top_words[1]:
        if w[0] == "salt":
            salt += 1
        elif w[0] =="sugar":
            sugar += 1
        elif w[0] =="water":
            water += 1
        elif w[0] =="mushrooms":
            mushrooms += 1
        elif w[0] =="chicken":
            chicken += 1
        elif w[0] =="eggs":
            eggs += 1 

save_answers1(salt, sugar,water,mushrooms,chicken,eggs)

# %%
def save_answers1(c_salt, c_sugar, c_water, c_mushrooms, c_chicken, c_eggs):
    with open("cooking_LDA_pa_task1.txt", "w") as fout:
        fout.write(" ".join([str(el) for el in [c_salt, c_sugar, c_water, c_mushrooms, c_chicken, c_eggs]]))

# %% [markdown]
# ### Фильтрация словаря
# В топах тем гораздо чаще встречаются первые три рассмотренных ингредиента, чем последние три. При этом наличие в рецепте курицы, яиц и грибов яснее дает понять, что мы будем готовить, чем наличие соли, сахара и воды. Таким образом, даже в рецептах есть слова, часто встречающиеся в текстах и не несущие смысловой нагрузки, и поэтому их не желательно видеть в темах. Наиболее простой прием борьбы с такими фоновыми элементами — фильтрация словаря по частоте. Обычно словарь фильтруют с двух сторон: убирают очень редкие слова (в целях экономии памяти) и очень частые слова (в целях повышения интерпретируемости тем). Мы уберем только частые слова.

# %%
import copy
dictionary2 = copy.deepcopy(dictionary)

# %% [markdown]
# __Задание 2.__ У объекта dictionary2 есть переменная *dfs* — это словарь, ключами которого являются id токена, а элементами — число раз, сколько слово встретилось во всей коллекции. Сохраните в отдельный список ингредиенты, которые встретились в коллекции больше 4000 раз. Вызовите метод словаря *filter_tokens*, подав в качестве первого аргумента полученный список популярных ингредиентов. Вычислите две величины: dict_size_before и dict_size_after — размер словаря до и после фильтрации.
#
# Затем, используя новый словарь, создайте новый корпус документов, corpus2, по аналогии с тем, как это сделано в начале ноутбука. Вычислите две величины: corpus_size_before и corpus_size_after — суммарное количество ингредиентов в корпусе (для каждого документа вычислите число различных ингредиентов в нем и просуммируйте по всем документам) до и после фильтрации.
#
# Передайте величины dict_size_before, dict_size_after, corpus_size_before, corpus_size_after в функцию save_answers2 и загрузите сгенерированный файл в форму.

# %%
list_of_popular_ingreds = [key for key, v in dictionary2.dfs.items() if v > 4000]
print list_of_popular_ingreds
# Out:
# [3, 5, 11, 15, 18, 20, 29, 44, 52, 59, 104, 114]

# %%
dict_size_before = len(dictionary2.dfs)
print "dict_size_before = ", dict_size_before
dictionary2.filter_tokens(bad_ids=list_of_popular_ingreds)
dict_size_after = len(dictionary2.dfs)
print "dict_size_after = ", dict_size_after

# удалили 12 частовстречающихся слов
# Out:
# dict_size_before =  6714
# dict_size_after =  6702

# %%
corpus2 = [dictionary2.doc2bow(text) for text in texts]  # составляем корпус документов

# %%
# Длины словарей считаются с помощью функции len, количество токенов в коллекции - в цикле.
corpus_size_before = 0
for doc in corpus:
    corpus_size_before += len(doc)
print "corpus_size_before = ", corpus_size_before


corpus_size_after = 0
for doc in corpus2:
    corpus_size_after += len(doc)
print "corpus_size_after = ", corpus_size_after
# Out:
# corpus_size_before =  428249
# corpus_size_after =  343665

# %%
def save_answers2(dict_size_before, dict_size_after, corpus_size_before, corpus_size_after):
    with open("cooking_LDA_pa_task2.txt", "w") as fout:
        fout.write(" ".join([str(el) for el in [dict_size_before, dict_size_after, corpus_size_before, corpus_size_after]]))

# %%
save_answers2(dict_size_before, dict_size_after, corpus_size_before, corpus_size_after)

# %% [markdown]
# ### Сравнение когерентностей
# __Задание 3.__ Постройте еще одну модель по корпусу corpus2 и словарю dictionary2, остальные параметры оставьте такими же, как при первом построении модели. Сохраните новую модель в другую переменную (не перезаписывайте предыдущую модель). Не забудьте про фиксирование seed!
#
# Затем воспользуйтесь методом **top_topics** модели, чтобы вычислить ее когерентность. Передайте в качестве аргумента соответствующий модели корпус. Метод вернет список кортежей (топ токенов, когерентность), отсортированных по убыванию последней. Вычислите среднюю по всем темам когерентность для каждой из двух моделей и передайте в функцию save_answers3.

# %%
corpus3 = [dictionary2.doc2bow(text) for text in texts]  # составляем корпус документов
np.random.seed(76543)
# здесь код для построения модели:
# %time ldamodel2 = models.ldamodel.LdaModel(corpus3, id2word=dictionary, num_topics=40, passes=5)
# Out:
# CPU times: user 1min 49s, sys: 1.26 s, total: 1min 50s
# Wall time: 41.6 s

# %%
top_1 = ldamodel.top_topics(corpus)
top_2 = ldamodel2.top_topics(corpus3)

# %%
# гредер эти ответы не принимает т.к. разные версии библиотек, но ответ правильный
mean_1 = np.mean([coh[1] for coh in top_1])
mean_2 = np.mean([coh[1] for coh in top_2])

# %%
print mean_1, mean_2
# Out:
# -5.811377648860752 -8.396678185515029

# %%
top_2
# Out:
# [([(0.0527468, u'fresh ginger root'),
#    (0.04797056, u'yellow onion'),
#    (0.047811348, u'scallions'),
#    (0.045286976, u'boneless chicken skinless thigh'),
#    (0.039315622, u'sea salt'),
#    (0.03823059, u'dark brown sugar'),
#    (0.02824026, u'mozzarella cheese'),
#    (0.027772995, u'almond extract'),
#    (0.0275857, u'saffron threads'),
#    (0.02495706, u'chunky salsa'),
#    (0.02450738, u'milk'),
#    (0.022179432, u'olive oil'),
#    (0.02205057, u'kahl\xfaa'),
#    (0.020385234, u'finely chopped fresh parsley'),
#    (0.019419288, u'chipotle chile'),
#    (0.0184733, u'passata'),
#    (0.017563703, u'sherry'),
#    (0.01648927, u'grape tomatoes'),
#    (0.016312458, u'chinese chives'),
#    (0.016177157, u'white pepper')],
#   -2.448792514335644),
#  ([(0.058523275, u'pepperoni'),
#    (0.043241117, u'vegetable oil'),
#    (0.041011218, u'dried chickpeas'),
#    (0.040158533, u'leeks'),
#    (0.039318793, u'egg bread'),
#    (0.03842873, u'bay leaf'),
#    (0.035324283, u'lemongrass'),
#    (0.031861294, u'milk'),
#    (0.028578784, u'yellow onion'),
#    (0.028475842, u'foie gras'),
#    (0.026404025, u'cornflour'),
#    (0.024823615, u'instant espresso granules'),
#    (0.021353405, u'chopped fresh chives'),
#    (0.019973485, u'asparagus tips'),
#    (0.018664809, u'black pepper'),
#    (0.018331433, u'Madeira'),
#    (0.017895227, u'cheese'),
#    (0.016780538, u'white sugar'),
#    (0.016083978, u'crusty rolls'),
#    (0.01589545, u'instant espresso powder')],
#   -2.6574299911194674),
#  ([(0.12792984, u'chicken livers'),
#    (0.072494924, u'swiss cheese'),
#    (0.0577323, u'sweet pepper'),
#    (0.0437903, u'lemongrass'),
#    (0.04298584, u'chinese chives'),
#    (0.030994, u'roasted peanuts'),
#    (0.030215036, u'chile pepper'),
#    (0.029155288, u'canola oil'),
#    (0.025157055, u'Shaoxing wine'),
#    (0.024628766, u'dried thyme'),
#    (0.022311293, u'yellow cake mix'),
#    (0.019850181, u'pimentos'),
#    (0.018589925, u'romaine lettuce'),
#    (0.01781445, u'red pepper'),
#    (0.017725024, u'yellow peppers'),
#    (0.016476015, u'cornflour'),
#    (0.015783623, u'grapefruit juice'),
#    (0.015768608, u'lemon olive oil'),
#    (0.015078211, u'mango'),
#    (0.0142341545, u'orange bell pepper')],
#   -2.9027085874315843),
#  ([(0.11097189, u'cajun seasoning'),
#    (0.06285531, u'garam masala'),
#    (0.06196312, u'ghee'),
#    (0.05649068, u'chipotle chile'),
#    (0.0545366, u'almond extract'),
#    (0.03783765, u'instant espresso granules'),
#    (0.037043646, u'wasabi'),
#    (0.033172123, u'coarse salt'),
#    (0.028216284, u'capers'),
#    (0.028042255, u'greek yogurt'),
#    (0.025628397, u'zesty italian dressing'),
#    (0.025276193, u'saffron threads'),
#    (0.020407207, u'flour tortillas'),
#    (0.019190889, u'sweet pepper'),
#    (0.018900238, u'jasmine rice'),
#    (0.018260848, u'fresh parsley'),
#    (0.018120712, u'grated Gruy\xe8re cheese'),
#    (0.017276855, u'chile pepper'),
#    (0.01667572, u'garlic chili sauce'),
#    (0.012075875, u'flour')],
#   -3.037615533554685),
#  ([(0.090880804, u'soy sauce'),
#    (0.08726326, u'tomatoes'),
#    (0.08128555, u'cabbage'),
#    (0.05879903, u'condiments'),
#    (0.056256063, u'golden brown sugar'),
#    (0.047836475, u'grilled chicken breasts'),
#    (0.042224962, u'large eggs'),
#    (0.03653956, u'sirloin tip roast'),
#    (0.02107649, u'beer'),
#    (0.019657161, u'chorizo sausage'),
#    (0.019405425, u'ground pepper'),
#    (0.019356756, u'chopped cilantro fresh'),
#    (0.018920088, u'silken tofu'),
#    (0.016829513, u'worcestershire sauce'),
#    (0.016246138, u'fresh pineapple'),
#    (0.016119277, u'yellow onion'),
#    (0.015605732, u'herbs'),
#    (0.014291008, u'cooking oil'),
#    (0.013284007, u'orzo'),
#    (0.012990396, u'sweet pepper')],
#   -3.061409109794405),
#  ([(0.08934952, u'boneless chicken skinless thigh'),
#    (0.056530107, u'Italian parsley leaves'),
#    (0.047077592, u'salami'),
#    (0.02958997, u'chopped fresh chives'),
#    (0.025517078, u'leeks'),
#    (0.024913844, u'soy sauce'),
#    (0.023953475, u'olive oil'),
#    (0.023674704, u'lean steak'),
#    (0.023317138, u'bay leaf'),
#    (0.023222247, u'orange juice concentrate'),
#    (0.02284174, u'lemon zest'),
#    (0.021757372, u'ground cumin'),
#    (0.02099907, u'pimentos'),
#    (0.020672338, u'cabbage'),
#    (0.02061249, u'heavy whipping cream'),
#    (0.020514833, u'pistachio nuts'),
#    (0.017052574, u'1% low-fat milk'),
#    (0.01616101, u'cayenne pepper'),
#    (0.015393356, u'ground flaxseed'),
#    (0.014998768, u'fat free less sodium beef broth')],
#   -3.350909404246179),
#  ([(0.06539739, u'canola oil'),
#    (0.056321006, u'dried thyme'),
#    (0.047334008, u'chicken livers'),
#    (0.045126032, u'pimentos'),
#    (0.04079377, u'chinese chives'),
#    (0.040466215, u'whole kernel corn, drain'),
#    (0.036320608, u'breakfast sausages'),
#    (0.032175973, u'garlic salt'),
#    (0.03129835, u'sharp cheddar cheese'),
#    (0.02717921, u'instant butterscotch pudding mix'),
#    (0.021225225, u'corn tortillas'),
#    (0.021176822, u'sweet pepper'),
#    (0.01845143, u'jasmine rice'),
#    (0.017779123, u'matcha green tea powder'),
#    (0.017264366, u'swiss cheese'),
#    (0.016498297, u'tomato sauce'),
#    (0.015636034, u'chile pepper'),
#    (0.015233893, u'instant espresso'),
#    (0.015057927, u'1% low-fat cottage cheese'),
#    (0.014766218, u'part-skim mozzarella cheese')],
#   -3.518809102335054),
#  ([(0.17684321, u'raspberries'),
#    (0.07386913, u'greek yogurt'),
#    (0.073715225, u'olive oil'),
#    (0.060260233, u'herbs'),
#    (0.048545394, u'trout fillet'),
#    (0.044003945, u'ground cinnamon'),
#    (0.030686202, u'hot red pepper flakes'),
#    (0.025849635, u'corn tortillas'),
#    (0.024550002, u'ancho chile pepper'),
#    (0.02453084, u'turbinado'),
#    (0.023029972, u'mace'),
#    (0.02273895, u'fresh ginger root'),
#    (0.022690803, u'chinese chives'),
#    (0.017773716, u'milk'),
#    (0.017740302, u'nonstick spray'),
#    (0.016644726, u'cream sweeten whip'),
#    (0.016316088, u'boneless chicken skinless thigh'),
#    (0.015056887, u'flour for dusting'),
#    (0.0141403945, u'corn oil'),
#    (0.012266856, u'grape tomatoes')],
#   -3.6573686300528094),
#  ([(0.09126185, u'fresh pineapple'),
#    (0.06917401, u'tomatillos'),
#    (0.06134865, u'low-fat sour cream'),
#    (0.058666676, u'onion powder'),
#    (0.053499144, u'chile powder'),
#    (0.03532341, u'tamari soy sauce'),
#    (0.033904865, u'dried black mushrooms'),
#    (0.028089156, u'chuck roast'),
#    (0.027303355, u'peanuts'),
#    (0.026649548, u'yellow crookneck squash'),
#    (0.024003204, u'dried oregano'),
#    (0.023892349, u'molasses'),
#    (0.02342714, u'canned black beans'),
#    (0.02284434, u'chopped green bell pepper'),
#    (0.02092297, u'mussels'),
#    (0.019910337, u'golden brown sugar'),
#    (0.018920982, u'oyster sauce'),
#    (0.015188498, u'burger buns'),
#    (0.014770535, u'cheddar cheese'),
#    (0.014286594, u'bell pepper')],
#   -3.70176140045701),
#  ([(0.14161259, u'chile pepper'),
#    (0.065972336, u'cheese'),
#    (0.04522911, u'green chilies'),
#    (0.041798737, u'curry paste'),
#    (0.03527135, u'low sodium beef broth'),
#    (0.030238241, u'ground pork'),
#    (0.029799527, u'finely chopped onion'),
#    (0.029497914, u'hazelnut oil'),
#    (0.029381081, u'worcestershire sauce'),
#    (0.029165346, u'milk'),
#    (0.029105922, u'bread slices'),
#    (0.028306449, u'2% reduced-fat milk'),
#    (0.026179248, u'dry mustard'),
#    (0.02564194, u'molasses'),
#    (0.024102438, u'pickled carrots'),
#    (0.023779763, u'low-fat sour cream'),
#    (0.020156499, u'sliced chicken'),
#    (0.018592583, u'cooking oil'),
#    (0.01690126, u'orzo pasta'),
#    (0.014397073, u'grilled chicken breasts')],
#   -3.8028563688511183),
#  ([(0.1651831, u'fresh ginger'),
#    (0.090118796, u'sage leaves'),
#    (0.056109726, u'white almond bark'),
#    (0.043865174, u'rice vinegar'),
#    (0.039144058, u'roma tomatoes'),
#    (0.031627435, u'steel-cut oats'),
#    (0.03039738, u'hominy'),
#    (0.028176494, u'extra sharp cheddar cheese'),
#    (0.02796236, u'chopped cilantro fresh'),
#    (0.023867296, u'spaghetti'),
#    (0.023244018, u'chipotle chile powder'),
#    (0.022601001, u'molasses'),
#    (0.022258764, u'garam masala'),
#    (0.022251422, u'garlic cloves'),
#    (0.021267602, u'baking powder'),
#    (0.020616302, u'baking potatoes'),
#    (0.016160566, u'cayenne pepper'),
#    (0.014167847, u'chinese five-spice powder'),
#    (0.013055357, u'ground ginger'),
#    (0.009930689, u'brioche bread')],
#   -4.01360012315484),
#  ([(0.10347344, u'glass noodles'),
#    (0.062219054, u'baking powder'),
#    (0.04395531, u'white almond bark'),
#    (0.0418351, u'unsweetened coconut milk'),
#    (0.035470292, u'stuffing'),
#    (0.035102572, u'epazote'),
#    (0.03466942, u'garam masala'),
#    (0.033950556, u'sirloin'),
#    (0.030052722, u'chees fresco queso'),
#    (0.029104184, u'dried black mushrooms'),
#    (0.028769618, u'jaggery'),
#    (0.026296752, u'crusty bread'),
#    (0.023535587, u'black bean sauce'),
#    (0.02121869, u'grilled chicken breasts'),
#    (0.020796122, u'low-fat mayonnaise'),
#    (0.020618321, u'chopped cilantro fresh'),
#    (0.019595817, u'quickcooking grits'),
#    (0.018472929, u'chorizo'),
#    (0.017955443, u'strawberries'),
#    (0.017687792, u'chinese five-spice powder')],
#   -4.224029437345281),
#  ([(0.17510913, u'sirloin'),
#    (0.12152523, u'sliced mushrooms'),
#    (0.09680377, u'light soy sauce'),
#    (0.07074012, u'fingerling potatoes'),
#    (0.06584659, u'cooked ham'),
#    (0.036697242, u'fat free less sodium chicken broth'),
#    (0.034333788, u'onions'),
#    (0.02239662, u'chopped cilantro fresh'),
#    (0.02123262, u'garlic paste'),
#    (0.018805474, u'canola oil'),
#    (0.017715516, u'parsnips'),
#    (0.016186653, u'vanilla extract'),
#    (0.01594267, u'cooked brown rice'),
#    (0.01502852, u'frozen corn'),
#    (0.014854811, u'extra firm tofu'),
#    (0.014704941, u'extra sharp cheddar cheese'),
#    (0.012883627, u'yellow mustard'),
#    (0.011360505, u'unsalted butter'),
#    (0.010610774, u'condensed cream of mushroom soup'),
#    (0.009999348, u'shiitake')],
#   -4.564988841017939),
#  ([(0.1345346, u'cornflour'),
#    (0.06189872, u'chicken broth'),
#    (0.05740312, u'lime juice'),
#    (0.054748792, u'thyme'),
#    (0.054330863, u'food colouring'),
#    (0.038565453, u'broccolini'),
#    (0.035328113, u'tumeric'),
#    (0.033580232, u'pecorino romano cheese'),
#    (0.029512059, u'green onions'),
#    (0.024023823, u'dried basil'),
#    (0.02343888, u'baby spinach leaves'),
#    (0.023120899, u'masa'),
#    (0.020541728, u'ketchup'),
#    (0.018041972, u'basmati rice'),
#    (0.0164796, u'crema mexicana'),
#    (0.015680876, u'old-fashioned oats'),
#    (0.0155819915, u'smoked paprika'),
#    (0.013931523, u'condiments'),
#    (0.013484269, u'chicken livers'),
#    (0.0126094185, u'romano cheese')],
#   -5.136381219256166),
#  ([(0.15804352, u'white almond bark'),
#    (0.08677426, u'english muffins, split and toasted'),
#    (0.06384894, u'chinese five-spice powder'),
#    (0.058235172, u'hibiscus'),
#    (0.043447535, u'chopped cilantro fresh'),
#    (0.04262477, u'dry sherry'),
#    (0.037604965, u'fresh oregano'),
#    (0.028822483, u'ground veal'),
#    (0.028503306, u'milk'),
#    (0.02189021, u'kiwi'),
#    (0.020982938, u'green beans'),
#    (0.020417752, u'garam masala'),
#    (0.018558087, u'tuna'),
#    (0.018099202, u'grated orange'),
#    (0.01745811, u'shortening'),
#    (0.01654646, u'dried black mushrooms'),
#    (0.016299583, u'Sriracha'),
#    (0.015640853, u'roma tomatoes'),
#    (0.013501234, u'anchovy paste'),
#    (0.012145839, u'grilled chicken breasts')],
#   -5.146206492607614),
#  ([(0.15361221, u'romaine lettuce'),
#    (0.15211737, u'green tomatoes'),
#    (0.09659542, u'garlic paste'),
#    (0.0752094, u'chorizo sausage'),
#    (0.06124571, u'sake'),
#    (0.047127943, u'serrano chile'),
#    (0.036186434, u'sliced mushrooms'),
#    (0.025486967, u'firm tofu'),
#    (0.02451234, u'sirloin'),
#    (0.021843372, u'onions'),
#    (0.01940772, u'boneless pork loin'),
#    (0.018936194, u'sun-dried tomatoes in oil'),
#    (0.015985012, u'carbonated beverages'),
#    (0.015501694, u'pesto'),
#    (0.012048937, u'applewood smoked bacon'),
#    (0.011892587, u'plain flour'),
#    (0.010874273, u'kefalotyri'),
#    (0.00941271, u'chile sauce'),
#    (0.009087832, u'ground black pepper'),
#    (0.009040249, u'watercress')],
#   -5.453987593427813),
#  ([(0.14083083, u'vegetable stock'),
#    (0.055625405, u'flour tortillas'),
#    (0.050287247, u'ground pork'),
#    (0.04363251, u'green bell pepper'),
#    (0.037096743, u'chinese chives'),
#    (0.036016777, u'confectioners sugar'),
#    (0.03079288, u'herbs'),
#    (0.029821923, u'green papaya'),
#    (0.02981277, u'frozen edamame beans'),
#    (0.029075498, u'boneless chop pork'),
#    (0.023122136, u'molasses'),
#    (0.022750644, u'carrots'),
#    (0.021272883, u'onion powder'),
#    (0.021124862, u'brewed tea'),
#    (0.021117527, u'roasted tomatoes'),
#    (0.020089697, u'sweet and sour sauce'),
#    (0.016958088, u'worcestershire sauce'),
#    (0.01683487, u'duck drippings'),
#    (0.016464422, u'chopped green bell pepper'),
#    (0.016233526, u'navel oranges')],
#   -6.226387722856299),
#  ([(0.10680029, u'dried black mushrooms'),
#    (0.06999546, u'thai chile'),
#    (0.058962844, u'greens'),
#    (0.050081015, u'romaine lettuce'),
#    (0.049649753, u'myzithra'),
#    (0.047561456, u'naan'),
#    (0.039738167, u'white bread'),
#    (0.038308214, u'corn oil'),
#    (0.03584828, u'old bay seasoning'),
#    (0.035151906, u'fontina'),
#    (0.027615573, u'blood orange'),
#    (0.025068693, u'cheddar cheese'),
#    (0.023774814, u'Johnsonville Andouille Dinner Sausage'),
#    (0.020838954, u'white miso'),
#    (0.020757502, u'molasses'),
#    (0.02032996, u'great northern beans'),
#    (0.018612003, u'tomatoes'),
#    (0.018141553, u'konbu'),
#    (0.013287355, u'milk'),
#    (0.0112555465, u'coconut sugar')],
#   -6.660713678138109),
#  ([(0.16881938, u'grape tomatoes'),
#    (0.085910864, u'vegetable broth'),
#    (0.05333459, u'milk'),
#    (0.040309552, u'rum extract'),
#    (0.025775163, u'guacamole'),
#    (0.025612976, u'pepper'),
#    (0.024636317, u'asian fish sauce'),
#    (0.0245553, u'hamburger buns'),
#    (0.020630935, u'chili flakes'),
#    (0.020235267, u'mozzarella balls'),
#    (0.018945009, u'balsamic vinegar'),
#    (0.018829554, u'chopped cilantro fresh'),
#    (0.018826708, u'sambal ulek'),
#    (0.018259231, u'fresh pineapple'),
#    (0.01804371, u'lamb shanks'),
#    (0.01766138, u'white almond bark'),
#    (0.01715789, u'extra sharp cheddar cheese'),
#    (0.015806392, u'wish bone guacamol ranch dress'),
#    (0.0145355165, u'creamy peanut butter'),
#    (0.013045321, u'bean threads')],
#   -6.919191214264857),
#  ([(0.12056491, u'hot red pepper flakes'),
#    (0.118281394, u'chocolate morsels'),
#    (0.11207804, u'fine sea salt'),
#    (0.09829137, u'cheddar cheese'),
#    (0.06509127, u'ground turmeric'),
#    (0.05257698, u'Sriracha'),
#    (0.045279548, u'mayonaise'),
#    (0.040251087, u'frozen corn'),
#    (0.033229172, u'red enchilada sauce'),
#    (0.021622054, u'crust'),
#    (0.021075457, u'kimchi'),
#    (0.017280167, u'walnuts'),
#    (0.01709557, u'raspberries'),
#    (0.014154405, u'sliced mushrooms'),
#    (0.010664516, u'sweetener'),
#    (0.009303892, u'white almond bark'),
#    (0.0084120445, u'oyster mushrooms'),
#    (0.007896168, u'balsamic vinegar'),
#    (0.0069487393, u'whole peeled tomatoes'),
#    (0.006227432, u'vanilla wafers')],
#   -7.118934722734136),
#  ([(0.08067219, u'tahini'),
#    (0.067693055, u'grated lemon zest'),
#    (0.043177184, u'free range egg'),
#    (0.03394706, u'rice syrup'),
#    (0.031175109, u'ground cardamom'),
#    (0.02852868, u'white rum'),
#    (0.028142117, u'spring onions'),
#    (0.024761964, u'chipotle puree'),
#    (0.023184476, u'noodles'),
#    (0.023070399, u'red raspberries'),
#    (0.02175815, u'peas'),
#    (0.021289283, u'pitas'),
#    (0.01997981, u'grilled chicken breasts'),
#    (0.018819202, u'cooking oil'),
#    (0.018698778, u'ground ginger'),
#    (0.018284455, u'potatoes'),
#    (0.018045152, u'rosemary leaves'),
#    (0.016363882, u'extra sharp cheddar cheese'),
#    (0.015516662, u'chile sauce'),
#    (0.0148397945, u'chopped fresh thyme')],
#   -7.34309039256915),
#  ([(0.05455107, u'green peppercorns'),
#    (0.04786932, u'chestnuts'),
#    (0.042747784, u'spicy brown mustard'),
#    (0.042180076, u'sliced mushrooms'),
#    (0.041101653, u'curry'),
#    (0.03858771, u'hot red pepper flakes'),
#    (0.036728986, u'sliced green onions'),
#    (0.035504933, u'avocado'),
#    (0.034858737, u'grilled chicken breasts'),
#    (0.03339819, u'goji berries'),
#    (0.033028252, u'chile paste'),
#    (0.03209869, u'ground beef'),
#    (0.029867062, u'dried black mushrooms'),
#    (0.027926484, u'pickled jalapenos'),
#    (0.025297672, u'grated jack cheese'),
#    (0.024218954, u'broccoli rabe'),
#    (0.021334324, u'green cardamom'),
#    (0.020178625, u'methi leaves'),
#    (0.018741565, u'canned black beans'),
#    (0.01755118, u'dinner rolls')],
#   -7.990962973664644),
#  ([(0.15320188, u'lemon juice'),
#    (0.09317995, u'fresh rosemary'),
#    (0.06306191, u'membrillo'),
#    (0.057225496, u'star anise'),
#    (0.0498575, u'ground lamb'),
#    (0.048002705, u'natural yogurt'),
#    (0.04629379, u'raisins'),
#    (0.024671111, u'plain dry bread crumb'),
#    (0.023624435, u'cornmeal'),
#    (0.022624502, u'lime'),
#    (0.020044494, u'corn chips'),
#    (0.019476444, u'pappardelle'),
#    (0.018193133, u'shiitake'),
#    (0.01618594, u'bacon slices'),
#    (0.015175677, u'rocket leaves'),
#    (0.014948585, u'fat skimmed chicken broth'),
#    (0.0135131385, u'crabmeat'),
#    (0.011668817, u'essence'),
#    (0.011369079, u'gnocchi'),
#    (0.011272157, u'egg bread')],
#   -8.311779763345093),
#  ([(0.12005858, u'mozzarella cheese'),
#    (0.07299696, u'creole seasoning'),
#    (0.070324495, u'sherry'),
#    (0.06858015, u'hot pepper sauce'),
#    (0.062098276, u'heavy cream'),
#    (0.0446442, u'chunky salsa'),
#    (0.026770113, u'chinese chives'),
#    (0.022566749, u'chopped tomatoes'),
#    (0.021314567, u'mussels'),
#    (0.019201446, u'light tuna'),
#    (0.019041104, u'cauliflower'),
#    (0.018685507, u'chopped green chilies'),
#    (0.018566135, u'fresh coriander'),
#    (0.018404571, u'instant yeast'),
#    (0.017272936, u'okra'),
#    (0.01701721, u'artichoke hearts'),
#    (0.016577743, u'green mango'),
#    (0.013215894, u'tumeric'),
#    (0.012931734, u'white cornmeal'),
#    (0.0123941535, u'stewing beef')],
#   -10.100384195954488),
#  ([(0.09234593, u'crawfish'),
#    (0.08882512, u'minced beef'),
#    (0.083066955, u'onions'),
#    (0.059399698, u'oil'),
#    (0.056260526, u'parsnips'),
#    (0.042616818, u'short-grain rice'),
#    (0.035356905, u'sliced mushrooms'),
#    (0.03445731, u'cumin'),
#    (0.030394344, u'chopped garlic'),
#    (0.024751713, u'cardamom pods'),
#    (0.024395462, u'brown lentils'),
#    (0.021249339, u'ramps'),
#    (0.017254876, u'lemon pepper'),
#    (0.016267998, u'fresh mushrooms'),
#    (0.014922146, u'unflavored gelatin'),
#    (0.014182794, u'mexican chorizo'),
#    (0.012692518, u'fresh thyme leaves'),
#    (0.011567485, u'organic sugar'),
#    (0.010601699, u'black peppercorns'),
#    (0.009569009, u'brown cardamom')],
#   -10.163133199365628),
#  ([(0.1279534, u'jasmine rice'),
#    (0.07629953, u'rice flour'),
#    (0.05392601, u'bacon slices'),
#    (0.044539843, u'Mexican beer'),
#    (0.040543083, u'garlic'),
#    (0.039224062, u'chocolate bars'),
#    (0.035687573, u'corn kernels'),
#    (0.03332318, u'fresh mushrooms'),
#    (0.032475594, u'ricotta'),
#    (0.027694399, u'club soda'),
#    (0.027291289, u'black sesame seeds'),
#    (0.027077002, u'rice paper'),
#    (0.022082986, u'cherry preserves'),
#    (0.020458411, u'chopped celery'),
#    (0.019819362, u'dri leav thyme'),
#    (0.01805715, u'slivered almonds'),
#    (0.017732065, u'red wine'),
#    (0.013800116, u'shiitake'),
#    (0.0131155895, u'chile sauce'),
#    (0.012324404, u'frisee')],
#   -11.09896651922401),
#  ([(0.09422284, u'shredded cabbage'),
#    (0.07738066, u'canned black beans'),
#    (0.056621276, u'sweet onion'),
#    (0.046683267, u'lime wedges'),
#    (0.042586498, u'oregano'),
#    (0.041719835, u'yellow bell pepper'),
#    (0.0326879, u'cold water'),
#    (0.030464157, u'dried red chile peppers'),
#    (0.028692827, u'chili paste'),
#    (0.024120262, u'chocolate instant pudding'),
#    (0.020654393, u'thai green curry paste'),
#    (0.020633876, u'paprika'),
#    (0.020215046, u'enchilada sauce'),
#    (0.017734187, u'Sargento\xae Traditional Cut Shredded Mozzarella Cheese'),
#    (0.017392876, u'grilled chicken breasts'),
#    (0.015855994, u'broiler-fryer chicken'),
#    (0.015852738, u'sugar pea'),
#    (0.0158375, u'liquid'),
#    (0.012907548, u'cannelloni shells'),
#    (0.012843981, u'baking apples')],
#   -11.499935371505686),
#  ([(0.07385331, u'onion tops'),
#    (0.05832814, u'mung bean sprouts'),
#    (0.057798304, u'condensed cream of mushroom soup'),
#    (0.05301575, u'dough'),
#    (0.043511566, u'white onion'),
#    (0.03880596, u'fennel bulb'),
#    (0.03622967, u'octopuses'),
#    (0.035300244, u'dried minced onion'),
#    (0.035089064, u'seasoning salt'),
#    (0.03500965, u'clam juice'),
#    (0.034758896, u'country ham'),
#    (0.033678688, u'tapioca flour'),
#    (0.032339014, u'bottled clam juice'),
#    (0.02480037, u'apple juice'),
#    (0.023322234, u'purple onion'),
#    (0.0225774, u'low sodium soy sauce'),
#    (0.021852538, u'candied orange peel'),
#    (0.020593092, u'kashmiri chile'),
#    (0.01923685, u'whole wheat lasagna noodles'),
#    (0.016283147, u'red radishes')],
#   -12.024864502821657),
#  ([(0.103103876, u'tamarind paste'),
#    (0.08806121, u'tostada shells'),
#    (0.07014472, u'sweet and sour sauce'),
#    (0.041529264, u'canned low sodium chicken broth'),
#    (0.03391593, u'sliced mushrooms'),
#    (0.03387008, u'preserved lemon'),
#    (0.033075597, u'cream'),
#    (0.02528406, u'condensed cheddar cheese soup'),
#    (0.01975569, u'lettuce leaves'),
#    (0.01891936, u'baby portobello mushrooms'),
#    (0.018107813, u'serrano chile'),
#    (0.017837282, u'shallots'),
#    (0.01766274, u'frosting'),
#    (0.015767466, u'black vinegar'),
#    (0.015735563, u'dried lentils'),
#    (0.015698425, u'seasoning'),
#    (0.014937581, u'chicken breast halves'),
#    (0.0131650185, u'mung bean sprouts'),
#    (0.013060963, u'cream cheese, soften'),
#    (0.012269463, u'sesame paste')],
#   -12.194022745476023),
#  ([(0.07775548, u'fenugreek seeds'),
#    (0.063953415, u'red wine vinegar'),
#    (0.05273037, u'basil leaves'),
#    (0.050794102, u'mustard powder'),
#    (0.0461772, u'ketchup'),
#    (0.040883444, u'scallion greens'),
#    (0.03445711, u'peppercorns'),
#    (0.032766875, u'pork ribs'),
#    (0.027848028, u'porcini'),
#    (0.026064087, u'pineapple juice'),
#    (0.02594598, u'penne'),
#    (0.025635866, u'water'),
#    (0.023090767, u'harissa'),
#    (0.020897293, u'seafood seasoning'),
#    (0.017740883, u'hibiscus tea'),
#    (0.016844638, u'chicken'),
#    (0.015655003, u'liquorice'),
#    (0.014632517, u'soda'),
#    (0.012720101, u'saltines'),
#    (0.012709897, u'grilled chicken breasts')],
#   -12.815841321010337),
#  ([(0.100839995, u'panko breadcrumbs'),
#    (0.06675173, u'jumbo shrimp'),
#    (0.052033696, u'dark soy sauce'),
#    (0.04855095, u'sourdough baguette'),
#    (0.044130683, u'cooked rice'),
#    (0.04314059, u'ice cubes'),
#    (0.033896778, u'organic chicken'),
#    (0.030454336, u'romaine lettuce'),
#    (0.025696363, u'linguine'),
#    (0.025493884, u'brown sugar'),
#    (0.024799833, u'dried cranberries'),
#    (0.021358911, u'hoisin sauce'),
#    (0.020744588, u'fresh lime juice'),
#    (0.020474084, u'sourdough'),
#    (0.019941889, u'Splenda Brown Sugar Blend'),
#    (0.017827487, u'hot chili'),
#    (0.017425124, u'mulato chiles'),
#    (0.017123893, u'chili paste with garlic'),
#    (0.01427541, u'broccolini'),
#    (0.01394413, u'button mushrooms')],
#   -12.816759929959877),
#  ([(0.16752738, u'butter'),
#    (0.09237175, u'white wine'),
#    (0.047679015, u'dried dillweed'),
#    (0.047204092, u'medium shrimp'),
#    (0.042931672, u'brewed coffee'),
#    (0.040095016, u'vegetable shortening'),
#    (0.03233121, u'plain flour'),
#    (0.029205298, u'fino sherry'),
#    (0.026133267, u'boiling water'),
#    (0.023783248, u'coconut flour'),
#    (0.018946202, u'starchy potatoes'),
#    (0.016461976, u'bulgur'),
#    (0.016332548, u'chinese chives'),
#    (0.015780197, u'powdered sugar'),
#    (0.014829868, u'fresh chorizo'),
#    (0.013158507, u'yeast'),
#    (0.013156444, u'parmigiano reggiano cheese'),
#    (0.012751789, u'baby lima beans'),
#    (0.011936335, u'albacore tuna in water'),
#    (0.011889232, u'grana padano')],
#   -13.335478754014227),
#  ([(0.13769616, u'firm tofu'),
#    (0.101372875, u'sugar'),
#    (0.09166264, u'crushed red pepper'),
#    (0.049627345, u'shredded mozzarella cheese'),
#    (0.039480172, u'fresh mint'),
#    (0.03837483, u'olives'),
#    (0.03535079, u'pappardelle pasta'),
#    (0.027027184, u'broccoli'),
#    (0.021788271, u'cilantro leaves'),
#    (0.017979717, u'freshly ground pepper'),
#    (0.015390918, u'lo mein noodles'),
#    (0.015005946, u'low salt chicken broth'),
#    (0.014557824, u'refrigerated crescent rolls'),
#    (0.014080963, u'almond extract'),
#    (0.013701697, u'apple cider vinegar'),
#    (0.012966903, u'tofu'),
#    (0.012734562, u'powdered buttermilk'),
#    (0.012345194, u"soft goat's cheese"),
#    (0.01167843, u'umeboshi vinegar'),
#    (0.011467781, u'ham hock')],
#   -13.396661048488438),
#  ([(0.062410202, u'mussels'),
#    (0.053764943, u'red bell pepper'),
#    (0.043943033, u'black olives'),
#    (0.043725777, u'fennel'),
#    (0.043524474, u'cachaca'),
#    (0.043508377, u'chopped walnuts'),
#    (0.03951558, u'sundried tomato paste'),
#    (0.03426063, u'zucchini'),
#    (0.027992059, u'edamame'),
#    (0.024979437, u'seasoned bread crumbs'),
#    (0.0242133, u'chinese chives'),
#    (0.02112578, u'turkey breast cutlets'),
#    (0.020887604, u'taco sauce'),
#    (0.018221244, u'whole grain mustard'),
#    (0.017468208, u'corn grits'),
#    (0.017426366, u'chili oil'),
#    (0.015341422, u'dark rum'),
#    (0.015310633, u'chopped parsley'),
#    (0.013712329, u'lemon soda'),
#    (0.0136262085, u'spiced rum')],
#   -13.446041814703564),
#  ([(0.07428956, u'eggs'),
#    (0.06834111, u'asiago'),
#    (0.06353038, u'basil'),
#    (0.050067555, u'chili flakes'),
#    (0.04911088, u'bosc pears'),
#    (0.041070722, u'peasant bread'),
#    (0.040783327, u'cheese slices'),
#    (0.0368948, u'miso'),
#    (0.031318087, u'duck breast halves'),
#    (0.029764622, u'sliced mushrooms'),
#    (0.024775198, u'white wine'),
#    (0.022119945, u'okra pods'),
#    (0.019390138, u'allspice berries'),
#    (0.018192712, u'cooked turkey'),
#    (0.017763967, u'ground chipotle chile pepper'),
#    (0.017662162, u'lean ground beef'),
#    (0.016784376, u'roast turkey'),
#    (0.016615573, u'summer squash'),
#    (0.015787348, u'warm water'),
#    (0.015072648, u'crema')],
#   -13.821291463248567),
#  ([(0.06570231, u'feta cheese crumbles'),
#    (0.053378806, u'Madeira'),
#    (0.050861344, u'whiskey'),
#    (0.04921401, u'cooked white rice'),
#    (0.041928556, u'pasta sauce'),
#    (0.038530063, u'pork'),
#    (0.036886353, u'pico de gallo'),
#    (0.033738084, u'cinnamon sugar'),
#    (0.028497359, u'whipping cream'),
#    (0.025878862, u'Greek feta'),
#    (0.024200039, u'cardamom'),
#    (0.021170422, u'sunflower oil'),
#    (0.02042753, u'flaked coconut'),
#    (0.01990955, u'ground cloves'),
#    (0.019423664, u'buttercream frosting'),
#    (0.01778876, u'greek seasoning'),
#    (0.016365455, u'angel food cake mix'),
#    (0.016122166, u'pizza crust'),
#    (0.014929035, u'worcestershire sauce'),
#    (0.013388539, u'chicken cutlets')],
#   -13.855973086873519),
#  ([(0.056045678, u'broiler-fryer chicken'),
#    (0.045197017, u'mexican chocolate'),
#    (0.04380167, u'red lentils'),
#    (0.04230391, u'chili garlic paste'),
#    (0.03801639, u'dried navy beans'),
#    (0.03693782, u'leg of lamb'),
#    (0.032687254, u'tomato ketchup'),
#    (0.032165002, u'italian seasoning'),
#    (0.031334244, u'semi-sweet chocolate morsels'),
#    (0.031297404, u'lettuce'),
#    (0.029730098, u'parmesan cheese'),
#    (0.02959268, u'deli ham'),
#    (0.027720243, u'ground red pepper'),
#    (0.022457756, u'mustard oil'),
#    (0.019891595, u'chicken wings'),
#    (0.01972589, u'coriander seeds'),
#    (0.01929098, u'whole nutmegs'),
#    (0.018943338, u'reduced-fat cheese'),
#    (0.01716983, u'chestnut flour'),
#    (0.016644744, u'pistachios')],
#   -14.294319994471953),
#  ([(0.12052131, u'egg roll wrappers'),
#    (0.079600565, u'rice noodles'),
#    (0.07476876, u'Oscar Mayer Deli Fresh Smoked Ham'),
#    (0.064574726, u'beef bouillon granules'),
#    (0.031624414, u'mushrooms'),
#    (0.026208375, u'paneer cheese'),
#    (0.024051564, u'corn'),
#    (0.021519454, u'fresh cilantro'),
#    (0.020803718, u'pumpkin pur\xe9e'),
#    (0.019956756, u'bok choy'),
#    (0.018022813, u'marshmallows'),
#    (0.01776415, u'green olives'),
#    (0.0154518355, u'shredded reduced fat cheddar cheese'),
#    (0.015431362, u'corned beef'),
#    (0.014619348, u'fryer chickens'),
#    (0.013375074, u'andouille sausage links'),
#    (0.013130747, u'fire roasted diced tomatoes'),
#    (0.0122764995, u'red kidnei beans, rins and drain'),
#    (0.012093293, u'chutney'),
#    (0.012036174, u'daikon')],
#   -15.338230683932574),
#  ([(0.08265644, u'all-purpose flour'),
#    (0.080693, u'provolone cheese'),
#    (0.05074265, u'fresh lemon juice'),
#    (0.0475554, u'rose petals'),
#    (0.041259468, u'Flora Cuisine'),
#    (0.038499825, u'sausages'),
#    (0.036956627, u'chinese cabbage'),
#    (0.03012711, u'cracked black pepper'),
#    (0.027149474, u'mixed greens'),
#    (0.025231553, u'sausage casings'),
#    (0.023331743, u'hot cocoa mix'),
#    (0.022481184, u'sherry vinegar'),
#    (0.02247533, u'lamb loin chops'),
#    (0.020993058, u'margarita mix'),
#    (0.020513525, u'pecans'),
#    (0.019092064, u'mushroom powder'),
#    (0.018578855, u'raw cashews'),
#    (0.017480087, u'moong dal'),
#    (0.016981049, u'feta cheese crumbles'),
#    (0.01420802, u'Equal Sweetener')],
#   -16.607064951055754),
#  ([(0.12437932, u'apple cider'),
#    (0.08798726, u'cinnamon graham crackers'),
#    (0.055590376, u'curly endive'),
#    (0.054509453, u'vidalia'),
#    (0.053293705, u'chickpea flour'),
#    (0.034268178, u'fennel seeds'),
#    (0.029577373, u'seafood stock'),
#    (0.0283825, u'poblano peppers'),
#    (0.023536168, u'yardlong beans'),
#    (0.022283964, u'monterey jack'),
#    (0.021232441, u'hothouse cucumber'),
#    (0.020404361, u'arborio rice'),
#    (0.019356104, u'cherries'),
#    (0.019005418, u'fresh tarragon'),
#    (0.018572828, u'white rice'),
#    (0.0180448, u'smoked ham hocks'),
#    (0.015088992, u'dried parsley'),
#    (0.014931398, u'reduced fat cream cheese'),
#    (0.01432904, u'portabello mushroom'),
#    (0.01415664, u'extra-virgin olive oil')],
#   -17.808243021934906)]

# %%
def save_answers3(coherence, coherence2):
    with open("cooking_LDA_pa_task3.txt", "w") as fout:
        fout.write(" ".join(["%3f"%el for el in [coherence, coherence2]]))

# %%
save_answers3(-703.2019367755069, -747.6959617371538)

# %% [markdown]
# Считается, что когерентность хорошо соотносится с человеческими оценками интерпретируемости тем. Поэтому на больших текстовых коллекциях когерентность обычно повышается, если убрать фоновую лексику. Однако в нашем случае этого не произошло.

# %% [markdown]
# ### Изучение влияния гиперпараметра alpha

# %% [markdown]
# В этом разделе мы будем работать со второй моделью, то есть той, которая построена по сокращенному корпусу.
#
# Пока что мы посмотрели только на матрицу темы-слова, теперь давайте посмотрим на матрицу темы-документы. Выведите темы для нулевого (или любого другого) документа из корпуса, воспользовавшись методом *get_document_topics* второй модели:

# %% [markdown]
# Также выведите содержимое переменной *.alpha* второй модели:

# %% [markdown]
# У вас должно получиться, что документ характеризуется небольшим числом тем. Попробуем поменять гиперпараметр alpha, задающий априорное распределение Дирихле для распределений тем в документах.

# %% [markdown]
# __Задание 4.__ Обучите третью модель: используйте сокращенный корпус (corpus2 и dictionary2) и установите параметр __alpha=1__, passes=5. Не забудьте про фиксацию seed! Выведите темы новой модели для нулевого документа; должно получиться, что распределение над множеством тем практически равномерное. Чтобы убедиться в том, что во второй модели документы описываются гораздо более разреженными распределениями, чем в третьей, посчитайте суммарное количество элементов, __превосходящих 0.01__, в матрицах темы-документы обеих моделей. Другими словами, запросите темы  модели для каждого документа с параметром *minimum_probability=0.01* и просуммируйте число элементов в получаемых массивах. Передайте две суммы (сначала для модели с alpha по умолчанию, затем для модели в alpha=1) в функцию save_answers4.

# %%
def save_answers4(count_model2, count_model3):
    with open("cooking_LDA_pa_task4.txt", "w") as fout:
        fout.write(" ".join([str(el) for el in [count_model2, count_model3]]))

# %% [markdown]
# Таким образом, гиперпараметр __alpha__ влияет на разреженность распределений тем в документах. Аналогично гиперпараметр __eta__ влияет на разреженность распределений слов в темах.

# %% [markdown]
# ### LDA как способ понижения размерности
# Иногда, распределения над темами, найденные с помощью LDA, добавляют в матрицу объекты-признаки как дополнительные, семантические, признаки, и это может улучшить качество решения задачи. Для простоты давайте просто обучим классификатор рецептов на кухни на признаках, полученных из LDA, и измерим точность (accuracy).
#
# __Задание 5.__ Используйте модель, построенную по сокращенной выборке с alpha по умолчанию (вторую модель). Составьте матрицу $\Theta = p(t|d)$ вероятностей тем в документах; вы можете использовать тот же метод get_document_topics, а также вектор правильных ответов y (в том же порядке, в котором рецепты идут в переменной recipes). Создайте объект RandomForestClassifier со 100 деревьями, с помощью функции cross_val_score вычислите среднюю accuracy по трем фолдам (перемешивать данные не нужно) и передайте в функцию save_answers5.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import cross_val_score

# %%
def save_answers5(accuracy):
     with open("cooking_LDA_pa_task5.txt", "w") as fout:
        fout.write(str(accuracy))

# %% [markdown]
# Для такого большого количества классов это неплохая точность. Вы можете попроовать обучать RandomForest на исходной матрице частот слов, имеющей значительно большую размерность, и увидеть, что accuracy увеличивается на 10–15%. Таким образом, LDA собрал не всю, но достаточно большую часть информации из выборки, в матрице низкого ранга.

# %% [markdown]
# ### LDA — вероятностная модель
# Матричное разложение, использующееся в LDA, интерпретируется как следующий процесс генерации документов.
#
# Для документа $d$ длины $n_d$:
# 1. Из априорного распределения Дирихле с параметром alpha сгенерировать распределение над множеством тем: $\theta_d \sim Dirichlet(\alpha)$
# 1. Для каждого слова $w = 1, \dots, n_d$:
#     1. Сгенерировать тему из дискретного распределения $t \sim \theta_{d}$
#     1. Сгенерировать слово из дискретного распределения $w \sim \phi_{t}$.
#
# Подробнее об этом в [Википедии](https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation).
#
# В контексте нашей задачи получается, что, используя данный генеративный процесс, можно создавать новые рецепты. Вы можете передать в функцию модель и число ингредиентов и сгенерировать рецепт :)

# %%
def generate_recipe(model, num_ingredients):
    theta = np.random.dirichlet(model.alpha)
    for i in range(num_ingredients):
        t = np.random.choice(np.arange(model.num_topics), p=theta)
        topic = model.show_topic(t, topn=model.num_terms)
        topic_distr = [x[1] for x in topic]
        terms = [x[0] for x in topic]
        w = np.random.choice(terms, p=topic_distr)
        print w

# %% [markdown]
# ### Интерпретация построенной модели
# Вы можете рассмотреть топы ингредиентов каждой темы. Большиснтво тем сами по себе похожи на рецепты; в некоторых собираются продукты одного вида, например, свежие фрукты или разные виды сыра.
#
# Попробуем эмпирически соотнести наши темы с национальными кухнями (cuisine). Построим матрицу $A$ размера темы $x$ кухни, ее элементы $a_{tc}$ — суммы $p(t|d)$ по всем документам $d$, которые отнесены к кухне $c$. Нормируем матрицу на частоты рецептов по разным кухням, чтобы избежать дисбаланса между кухнями. Следующая функция получает на вход объект модели, объект корпуса и исходные данные и возвращает нормированную матрицу $A$. Ее удобно визуализировать с помощью seaborn.

# %%
import pandas
import seaborn
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
def compute_topic_cuisine_matrix(model, corpus, recipes):
    # составляем вектор целевых признаков
    targets = list(set([recipe["cuisine"] for recipe in recipes]))
    # составляем матрицу
    tc_matrix = pandas.DataFrame(data=np.zeros((model.num_topics, len(targets))), columns=targets)
    for recipe, bow in zip(recipes, corpus):
        recipe_topic = model.get_document_topics(bow)
        for t, prob in recipe_topic:
            tc_matrix[recipe["cuisine"]][t] += prob
    # нормируем матрицу
    target_sums = pandas.DataFrame(data=np.zeros((1, len(targets))), columns=targets)
    for recipe in recipes:
        target_sums[recipe["cuisine"]] += 1
    return pandas.DataFrame(tc_matrix.values/target_sums.values, columns=tc_matrix.columns)

# %%
def plot_matrix(tc_matrix):
    plt.figure(figsize=(10, 10))
    seaborn.heatmap(tc_matrix, square=True)

# %%
# Визуализируйте матрицу

# %% [markdown]
# Чем темнее квадрат в матрице, тем больше связь этой темы с данной кухней. Мы видим, что у нас есть темы, которые связаны с несколькими кухнями. Такие темы показывают набор ингредиентов, которые популярны в кухнях нескольких народов, то есть указывают на схожесть кухонь этих народов. Некоторые темы распределены по всем кухням равномерно, они показывают наборы продуктов, которые часто используются в кулинарии всех стран.

# %% [markdown]
# Жаль, что в датасете нет названий рецептов, иначе темы было бы проще интерпретировать...

# %% [markdown]
# ### Заключение
# В этом задании вы построили несколько моделей LDA, посмотрели, на что влияют гиперпараметры модели и как можно использовать построенную модель.
